# %% [markdown]
# <a href="https://colab.research.google.com/github/jelder59/Python/blob/main/AulaPython1%20-%20Orrico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 Condicional
 if...elif...else

# %%
nome = input("Digite seu nome: ")
idade = input("Digite sua idade: ")
if (idade) >= '18':
    print("Olá", nome, "Pode tirar a CNH!!!")
else:
  print("Olá", nome,"Você não pode tirar a CNH!!!")
# Out:
# Digite seu nome: Elder
# Digite sua idade: 16
# Olá Elder Você não pode tirar a CNH!!!

# %%
nome  = input("Digite o nome do usuário: ")
salario = float(input('Digite o salário do usuário: R$'))
print(f'O salário do (a) {nome} é de R$ {salario}!!!')
if salario >= 1000:
  print (f'O(a) {nome} ganha bem!!!')
else:
  print(f'O(a) {nome} ganha pouquinho!!!')
# Out:
# Digite o nome do usuário: Elder
# Digite o salário do usuário: R$1200.00
# O salário do (a) Elder é de R$ 1200.0!!!
# O(a) Elder ganha bem!!!

# %%
nome = input("Digite seu nome: ")
n1 = int(input("Digite a primeira nota: "))
n2 = int(input("Digite a segunda nota: "))
n3 = int(input("Digite a terceira nota: "))
n4 = int(input("Digite a quarta nota: "))
media = (n1+n2+n3+n4)/4
if media >=7:
  print(f'{nome} sua média é {media} e você foi aprovado!')
elif media <5:
  print(f'[nome] sua média é {media} e você foi reprovado!')
else:
  print(f'{nome} sua média é {media} e você está de recuperação!')
# Out:
# Digite seu nome: Elder
# Digite a primeira nota: 5
# Digite a segunda nota: 8
# Digite a terceira nota: 4
# Digite a quarta nota: 9
# Elder sua média é 6.5 e você está de recuperação!

# %% [markdown]
# Match...case

# %%
time = input('Entre com o nome do seu time de futebol: ')
match time:
  case 'Flamengo '| 'Fluminense' | 'Vasco' | 'Botafogo':
    print('Este é um time carioca!!!')
  case 'São Paulo' | 'Santos' | 'Palmeiras'| 'Corinthians' | 'Juventus':
    print('Este é um time paulista!!!')
  case _: #outro caso
    print('Este é um time de outro estado!!!')
# Out:
# Entre com o nome do seu time de futebol: Bahia
# Este é um time de outro estado!!!

# %%
valor = float(input('Digite o valor da mercadoria:'))
op = int(input('Digite 1 para parcelar ou 2 para pagamento a vista: '))
match op:
  case 1:
    if valor > 1000:
      parcelas = valor/5
      print(f'Com esse valor você pode parcelar em 5 vezes de R$: {parcelas: .2f}')
    else:
      parcelas = valor/3
      print(f'Com esse valor você pode parcelar em 3 vezes de R$: {parcelas: .2f}')
  case 2:
    avista = (valor *0.9)
    print(f'O valor a vista é: {avista: .2f}')
  case _:
    print ('Opção Inválida!')
# Out:
# Digite o valor da mercadoria:900
# Digite 1 para parcelar ou 2 para pagamento a vista: 1
# Com esse valor você pode parcelar em 3 vezes de R$:  300.00

# %% [markdown]
# Repetição... while

# %%
cont = 0
n = int(input('Digite um número: '))
while cont <10:
  cont += 1
  m = cont * n
  print(f'{n} X {cont} = {m}')
print(f'Esta é a tabuada do {n}')
# Out:
# Digite um número: 6
# 6 X 1 = 6
# 6 X 2 = 12
# 6 X 3 = 18
# 6 X 4 = 24
# 6 X 5 = 30
# 6 X 6 = 36
# 6 X 7 = 42
# 6 X 8 = 48
# 6 X 9 = 54
# 6 X 10 = 60
# Esta é a tabuada do 6

# %%
print('|' '-' * 25,
      '|') # O 50 multiplica o caractere
print('| ------ Sistema de conversão de moedas local ------')

qtd = int(input('Quantas conversões deseja fazer no momento?'))
cont = 0

while cont < qtd:
  cont += 1 # incremento
  reais = float (input('Qual o valor em Reais deseja converter: R$ '))
  dolar = float (input('Qual o valor do dolar hoje: ? '))
  valor = reais / dolar

  print(f'R$ {reais} em dolar é: US$ {valor: .2f}')
print('| ------ O SCML Agradece sua visita!!! ------|')
print('|', '-' * 50, '|')
# Out:
# |-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|- |
# | ------ Sistema de conversão de moedas local ------
# Quantas conversões deseja fazer no momento?1
# Qual o valor em Reais deseja converter: R$ 3000
# Qual o valor do dolar hoje: ? 5
# R$ 3000.0 em dolar é: US$  600.00
# | ------ O SCML Agradece sua visita!!! ------|
# | -------------------------------------------------- |

# %% [markdown]
# for

# %%
from re import X
n = int (input ('Digite o número da tabuada: '))
for x in range(1, 11): # o range ignora o último número
  print(f'{n} X {x} = {n * x}')
# Out:
# Digite o número da tabuada: 5
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 5 X 10 = 50

# %% [markdown]
# Exercício

# %%
qtd = int(input('Quantos produtos deseja comprar: '))

while qtd <=0:
  qtd = int(input('Digite um valor válido'))

total = 0

for i in range(1, qtd+1):
  valor = float(input(f'Digite o preço do produto {i}: '))

  while valor <=0:
    valor = float(input('Valor inválido. Digite novamente: '))
  total += valor

print (f'\n Total da compra: R$ {total: .2f}')

desconto = 0

if total > 100:
  desconto = total * 0.10
  total -= desconto

  print(f'Desconto aplicado: R$ {desconto: .2f}')

else:
  print('Sem desconto')

print(f'Valor após desconto: R$ {total: .2f}')

print('\nForma de pagamento:')
print('1 - À vista')
print('2 - Parcelado')

op = int(input('Escolha: '))

if op == 1:
  desc_pag = total * 0.05
  total -= desc_pag
  print(f'Desconto a vista: R$ {desc_pag:.2f}')

elif op == 2:
  print('Pagamento parcelado.')

else:
  print('Opção inválida')

print(f'\nValor final: R$ {total:.2f}')
# Out:
# Quantos produtos deseja comprar: 2
# Digite o preço do produto 1: 60
# Digite o preço do produto 2: 80
#
#  Total da compra: R$  140.00
# Desconto aplicado: R$  14.00
# Valor após desconto: R$  126.00
#
# Forma de pagamento:
# 1 - À vista
# 2 - Parcelado
# Escolha: 1
# Desconto a vista: R$ 6.30
#
# Valor final: R$ 119.70

# %% [markdown]
# Variáveis Compostas - Coleções /// Tuplas - Imutáveis

# %%
dados = ('João', 25, 'São Paulo') # tuplas parenteses - imutável

print('Dados completos')
print(dados)

print('\nNome')
print(dados[0])

print('\nIdade')
print(dados[1])

print('\nCidade')
print(dados[2])
# Out:
# Dados completos
# ('João', 25, 'São Paulo')
#
# Nome
# João
#
# Idade
# 25
#
# Cidade
# São Paulo

# %% [markdown]
# Exercício2

# %%
numeros =(10,5,20,8,15)

print(f'Menor valor: {min(numeros)}')
print(f'Maior valor: {max(numeros)}')

print(f'Soma dos valores: {sum(numeros)}')
# Out:
# Menor valor: 5
# Maior valor: 20
# Soma dos valores: 58

# %% [markdown]
# Listas - Caracteristica []

# %%
lista =[] # lista entre colchetes - Vetores

for i in range(5):
  produto = input(f'Digite o produto {i+1}: ')
  lista.append(produto)

print('\nLista de produtos: ')
for item in lista:
  print(item)

print(f'\nQuantidade de itens: {len(lista)}')

if 'Arroz' in lista:
  print('Arroz está na lista ')
else:
  print('Arroz não está na lista')
# Out:
# Digite o produto 1: Arroz
# Digite o produto 2: Feijão
# Digite o produto 3: Batata
# Digite o produto 4: Laranja
# Digite o produto 5: Banana
#
# Lista de produtos:
# Arroz
# Feijão
# Batata
# Laranja
# Banana
#
# Quantidade de itens: 5
# Arroz está na lista

# %% [markdown]
# Dicionários {} # Chaves

# %%
aluno = {}

aluno ['nome'] = input('Digite o nome:')
aluno ['nota'] = float(input('Digite a nota: '))

print('\nDados do aluno')
print(aluno)

if aluno['nota'] >= 7:
  print('Aprovado')
else:
  print('Reprovado')
# Out:
# Digite o nome:Elder
# Digite a nota: 5
#
# Dados do aluno
# {'nome': 'Elder', 'nota': 5.0}
# Reprovado

# %% [markdown]
# Funções -  Tarefas repetitivas para utilizar novamente no código - def

# %%
alunos = []
#----------------------Funções-------------------------

def cadastrar():
  aluno = {}
  aluno[1nome]= input('Digite o nome: ')
  aluno['nota'] = float(input('Digite a nota: '))
  alunos.append(aluno)
  print('Aluno cadastrado com sucesso!!!\n')

def listar():
  if len(alunos) == 0:
    print('Nenhum aluno cadastrado!!!\n')
    return
  print('\nLista de alunos: ')
  for a in alunos:
    print(f'Nome: {a["nome"]}  Nota: {a["nota"]}')
  print()

def buscar():
  nome = input('Digite o nome para buscar: ')
  for a in alunos:
    if a['nome'].lower() == nome.lower():
      print(f'Encontrado: {a["nome"]} Nota: {a["nota"]}\n')
      return
  print('Aluno não encontrado!!!\n')

def aprovados():
  print('\nAlunos aprovados: ')
  encontrou = False
  for a in alunos:
    if a['nota'] >= 7:
      print(f'{a["nome"]} Nota: {a["nota"]}')
      encontr
