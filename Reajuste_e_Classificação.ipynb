# %% [markdown]
# <a href="https://colab.research.google.com/github/jelder59/Python/blob/main/Reajuste_e_Classifica%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Calcular o aumento com classificação
def calcular_reajuste(salario):

    # 1. Salário Maior que 1500
    if salario > 1500.00:
        aumento = 25.00
    # 2. De 750 inclusive (>=) até 1500 inclusive (<=)
    elif salario >= 750.00 and salario <= 1500.00:
        aumento = 50.00
    # 3. De 450 inclusive (>=) a 750.
    elif salario >= 450.00 and salario < 750.00:
        aumento = 75.00
    # 4. Menor que 450
    elif salario < 450.00:
        aumento = 100.00
    else:
        aumento = 0.00

    # Calculamos o novo valor
    novo_salario = salario + aumento

    # Classificação do Novo Salário

    if novo_salario <= 700.00:
        classificacao = "Mal remunerado"
    else:
        classificacao = "Bem remunerado"

    # Mostramos o resultado
    print("---------------------------------")
    print(f"Salário Atual: R$ {salario:.2f}")
    print(f"Aumento Fixo:  R$ {aumento:.2f}")
    print(f"Novo Salário:  R$ {novo_salario:.2f}")
    print(f"Status:        {classificacao}")
    print("---------------------------------\n")

print("=== Sistema de Reajuste e Classificação ===")
print("")
print(" Para sair Digite 0.\n")

while True:
    salario_digitado = float(input("Digite o salário atual: R$ "))

    if salario_digitado <= 0:
        print("\nSaindo do programa. Até mais!")
        break # para sair do while True

    calcular_reajuste(salario_digitado)
# Out:
# === Sistema de Reajuste e Classificação ===
#
#  Para sair Digite 0.
#
# Digite o salário atual: R$ 500
# ---------------------------------
# Salário Atual: R$ 500.00
# Aumento Fixo:  R$ 75.00
# Novo Salário:  R$ 575.00
# Status:        Mal remunerado
# ---------------------------------
#
# Digite o salário atual: R$ 550
# ---------------------------------
# Salário Atual: R$ 550.00
# Aumento Fixo:  R$ 75.00
# Novo Salário:  R$ 625.00
# Status:        Mal remunerado
# ---------------------------------
#
# Digite o salário atual: R$ 600
# ---------------------------------
# Salário Atual: R$ 600.00
# Aumento Fixo:  R$ 75.00
# Novo Salário:  R$ 675.00
# Status:        Mal remunerado
# ---------------------------------
#
# Digite o salário atual: R$ 700
# ---------------------------------
# Salário Atual: R$ 700.00
# Aumento Fixo:  R$ 75.00
# Novo Salário:  R$ 775.00
# Status:        Bem remunerado
# ---------------------------------
#
# Digite o salário atual: R$ 680
# ...
